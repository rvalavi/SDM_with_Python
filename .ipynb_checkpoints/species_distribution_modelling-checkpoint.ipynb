# %%
# %matplotlib inline

# %%
import xarray as xr
import rioxarray as rxr
import numpy as np
import pandas as pd
import geowombat as gw # remote sensing and spatial operations
import geopandas as gpd

# import dask
# from dask.distributed import Client, LocalCluster

import matplotlib.pyplot as plt
import os
import glob
from tqdm.notebook import tqdm

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
import os
os.getcwd()
# Out:
# '/home/rvalavi/Documents/SDM_with_Python'

# %%
# %dirs
# Out:
# []

# %% [markdown]
# Read all the TIFF files in the directory.

# %%
rlist = glob.glob("Rasters/*.tif")
rlist
# Out:
# ['Rasters/tempann.tif',
#  'Rasters/vegsys.tif',
#  'Rasters/solrad.tif',
#  'Rasters/topo.tif',
#  'Rasters/raindq.tif',
#  'Rasters/cti.tif',
#  'Rasters/mi.tif',
#  'Rasters/soildepth.tif',
#  'Rasters/rugged.tif',
#  'Rasters/rainann.tif',
#  'Rasters/soilfert.tif',
#  'Rasters/tempmin.tif',
#  'Rasters/disturb.tif']

# %%
# %%time
plt.figure(figsize=(3,4))
tempann = rxr.open_rasterio('Rasters/tempann.tif', chunks={'x':1689, 'y':1797})
tempann[0::10, 0::10].plot()
# Out:
# CPU times: user 145 ms, sys: 62 ms, total: 207 ms
# Wall time: 239 ms

# %%
# import point data
points = pd.read_csv("Records/train_po/NSWtrain_po.csv")
points = points[points["spid"] == "nsw14"]
points.head()
# Out:
#         siteid   spid         x        y  occ group   cti  disturb  mi  \
# 1149  dbpo1152  nsw14  153.4879 -28.1642    1    db  1339        3  88
# 1150  dbpo1153  nsw14  153.4838 -28.1651    1    db  1439        3  88
# 1151  dbpo1154  nsw14  153.4930 -28.1696    1    db  1629        3  89
# 1152  dbpo1155  nsw14  152.5070 -28.2522    1    db  1259        2  92
# 1153  dbpo1156  nsw14  152.4990 -28.2567    1    db  1279        2  91
#
#       rainann  raindq  rugged  soildepth  soilfert  solrad  tempann  tempmin  \
# 1149     1590     216      11       1139         2      89      200       85
# 1150     1592     216      15       1149         2      89      199       84
# 1151     1594     222       1       1159         2      89      200       86
# 1152     1580     222      28       1080         2      86      159       45
# 1153     1568     222      51       1110         2      88      158       44
#
#       topo  vegsys
# 1149    -1       5
# 1150    -3       5
# 1151    -1       5
# 1152    -3       2
# 1153    -3       2

# %%
# get x and y coords for the points
x_coords = points["x"].values
y_coords = points["y"].values
x_coords.shape
# Out:
# (315,)

# %%
# import point data
points = pd.read_csv("Records/train_po/NSWtrain_po.csv")
points = points[points["spid"] == "nsw14"]
points = points[['occ', 'x', 'y']]
points.head()
# Out:
#       occ         x        y
# 1149    1  153.4879 -28.1642
# 1150    1  153.4838 -28.1651
# 1151    1  153.4930 -28.1696
# 1152    1  152.5070 -28.2522
# 1153    1  152.4990 -28.2567

# %%
gdf = gpd.GeoDataFrame(points, geometry=gpd.points_from_xy(points.x, points.y))
gdf.head()
# Out:
#       occ         x        y                     geometry
# 1149    1  153.4879 -28.1642  POINT (153.48790 -28.16420)
# 1150    1  153.4838 -28.1651  POINT (153.48380 -28.16510)
# 1151    1  153.4930 -28.1696  POINT (153.49300 -28.16960)
# 1152    1  152.5070 -28.2522  POINT (152.50700 -28.25220)
# 1153    1  152.4990 -28.2567  POINT (152.49900 -28.25670)

# %%
gdf.to_file('occurrence.gpkg', driver='GPKG', layer='name')

# %%
border = gpd.read_file("nsw.gpkg")

# %%
names = ['tempann','vegsys','solrad','topo','raindq','cti','mi','soildepth','rugged','rainann','soilfert','tempmin','disturb']
len(names), len(rlist)
# Out:
# (13, 13)

# %%
# %%time
with gw.open(rlist) as src:
    df = src.gw.extract('occurrence.gpkg', time_names=names, band_names=None)
# Out:
# CPU times: user 3.55 s, sys: 678 ms, total: 4.22 s
# Wall time: 3.26 s

# %%
# %%time
with gw.open(rlist, chunks=(1689, 1797)) as src:
    df = src.gw.extract('occurrence.gpkg', time_names=names, band_names=None)
# Out:
# CPU times: user 1.04 s, sys: 328 ms, total: 1.37 s
# Wall time: 992 ms

# %%
df.head()
# Out:
#    occ         x        y                     geometry  id  tempann_1  \
# 0    1  153.4879 -28.1642  POINT (153.48790 -28.16420)   0        200
# 1    1  153.4838 -28.1651  POINT (153.48380 -28.16510)   1        199
# 2    1  153.4930 -28.1696  POINT (153.49300 -28.16960)   2        200
# 3    1  152.5070 -28.2522  POINT (152.50700 -28.25220)   3        159
# 4    1  152.4990 -28.2567  POINT (152.49900 -28.25670)   4        158
#
#    vegsys_1  solrad_1  topo_1  raindq_1  cti_1  mi_1  soildepth_1  rugged_1  \
# 0         5        89      -1       216   1339    88         1139        11
# 1         5        89      -3       216   1439    88         1149        15
# 2         5        89      -1       222   1629    89         1159         1
# 3         2        86      -3       222   1259    92         1080        28
# 4         2        88      -3       222   1279    91         1110        51
#
#    rainann_1  soilfert_1  tempmin_1  disturb_1
# 0       1590           2         85          3
# 1       1592           2         84          3
# 2       1594           2         86          3
# 3       1580           2         45          2
# 4       1568           2         44          2

# %%
base = border.boundary.plot()
df.plot(ax=base, column='tempann_1')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modelling test with GeoWombat

# %%
from geowombat.data import l8_224078_20200518, l8_224078_20200518_polygons

# %%
from geowombat.ml import fit, predict, fit_predict
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
from sklearn.cluster import KMeans

# %%
from sklearn.model_selection import GridSearchCV, KFold
from sklearn_xarray.model_selection import CrossValidatorWrapper

# %%
le = LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
labels = gpd.read_file(l8_224078_20200518_polygons)
labels
# Out:
#         name                                           geometry
# 0      water  POLYGON ((737544.502 -2795232.772, 737544.502 ...
# 1       crop  POLYGON ((742517.658 -2798160.232, 743046.717 ...
# 2       tree  POLYGON ((742435.360 -2801875.403, 742458.874 ...
# 3  developed  POLYGON ((738903.667 -2811573.845, 738926.586 ...

# %%
labels['lc'] = le.fit(labels.name).transform(labels.name)
labels
# Out:
#         name                                           geometry  lc
# 0      water  POLYGON ((737544.502 -2795232.772, 737544.502 ...   3
# 1       crop  POLYGON ((742517.658 -2798160.232, 743046.717 ...   0
# 2       tree  POLYGON ((742435.360 -2801875.403, 742458.874 ...   2
# 3  developed  POLYGON ((738903.667 -2811573.845, 738926.586 ...   1

# %%
pl = Pipeline([('scaler', StandardScaler()),
                ('pca', PCA()),
                ('clf', GaussianNB())])

# %%
cv = CrossValidatorWrapper(KFold(n_splits=5))

# %%
gridsearch = GridSearchCV(pl, cv=cv, scoring='balanced_accuracy',
                          param_grid={"pca__n_components": [1, 2, 3]})

# %%
gridsearch
# Out:
# GridSearchCV(cv=<sklearn_xarray.model_selection.CrossValidatorWrapper object at 0x7f4dad3b1450>,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('pca', PCA()), ('clf', GaussianNB())]),
#              param_grid={'pca__n_components': [1, 2, 3]},
#              scoring='balanced_accuracy')

# %%
l8_224078_20200518
# Out:
# '/home/rvalavi/miniconda3/envs/spatial/lib/python3.10/site-packages/geowombat/data/LC08_L1TP_224078_20200518_20200518_01_RT.TIF'

# %%
with gw.config.update(ref_res=300):
    with gw.open(l8_224078_20200518) as src:
        X, Xy, clf = fit(src, pl, labels, col="lc")

# %%
gridsearch.fit(*Xy)
# Out:
# GridSearchCV(cv=<sklearn_xarray.model_selection.CrossValidatorWrapper object at 0x7f4dad3b1450>,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('pca', PCA()), ('clf', GaussianNB())]),
#              param_grid={'pca__n_components': [1, 2, 3]},
#              scoring='balanced_accuracy')

# %%
print(gridsearch.best_params_)
# Out:
# {'pca__n_components': 1}

# %%
print(gridsearch.best_score_)
# Out:
# 0.7333333333333333

# %%
clf.set_params(**gridsearch.best_params_)
# Out:
# Pipeline(steps=[('scaler',
#                  EstimatorWrapper(copy=True, estimator=StandardScaler(),
#                                   reshapes='band', with_mean=True,
#                                   with_std=True)),
#                 ('pca',
#                  EstimatorWrapper(copy=True, estimator=PCA(),
#                                   iterated_power='auto', n_components=1,
#                                   n_oversamples=10,
#                                   power_iteration_normalizer='auto',
#                                   random_state=None, reshapes='band',
#                                   svd_solver='auto', tol=0.0, whiten=False)),
#                 ('clf',
#                  EstimatorWrapper(estimator=GaussianNB(), priors=None,
#                                   reshapes='band', var_smoothing=1e-09))])

# %%
y1 = predict(src, X, clf)

# %%
y.plot(robust=True)

# %%
plt.tight_layout(pad=1)

# %% [markdown]
# # Test on the NSW data

# %% [markdown]
# ## Creating random background samples

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest

# %%
import numpy as np
from shapely.geometry import Point
import geopandas as gpd

def random_points_in_polygon(polygon, number):   
    minx, miny, maxx, maxy = polygon.bounds.values[0]
    x = np.random.uniform(minx, maxx, number)
    y = np.random.uniform(miny, maxy, number)
    
    df = pd.DataFrame()
    df['geometry'] = list(zip(x,y))
    df['geometry'] = df['geometry'].apply(Point)
    gdf_points = gpd.GeoDataFrame(df, geometry='geometry')
    
    Sjoin = gpd.tools.sjoin(gdf_points, polygon, predicate="within", how='left')

    # Keep points in "myPoly"
    pnts_in_poly = gdf_points[Sjoin.index_right==0]

    return pnts_in_poly

# %%
border = gpd.read_file("nsw.gpkg")

# %%
bg = random_points_in_polygon(border, 1_000)
bg.shape
# Out:
# (516, 1)

# %%
fig, ax = plt.subplots()

border.boundary.plot(ax=ax)
bg.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
bg['occ'] = 0
bg.head()
# Out:
#                       geometry  occ
# 1  POINT (152.20274 -29.59227)    0
# 3  POINT (152.84752 -28.41457)    0
# 4  POINT (152.37048 -28.79137)    0
# 5  POINT (151.87034 -32.40917)    0
# 8  POINT (152.48477 -30.76662)    0

# %%
# import point data
points = pd.read_csv("Records/train_po/NSWtrain_po.csv")
points = points[points["spid"] == "nsw14"]
points = points[['occ', 'x', 'y']]

# %%
gdf = gpd.GeoDataFrame(points, geometry=gpd.points_from_xy(points.x, points.y))
gdf[['occ', 'geometry']].head()
# Out:
#       occ                     geometry
# 1149    1  POINT (153.48790 -28.16420)
# 1150    1  POINT (153.48380 -28.16510)
# 1151    1  POINT (153.49300 -28.16960)
# 1152    1  POINT (152.50700 -28.25220)
# 1153    1  POINT (152.49900 -28.25670)

# %%
labels = pd.concat([gdf[['occ', 'geometry']], bg])
labels.to_file('occurrence.gpkg', driver='GPKG', layer='name')
labels.head()
# Out:
#       occ                     geometry
# 1149    1  POINT (153.48790 -28.16420)
# 1150    1  POINT (153.48380 -28.16510)
# 1151    1  POINT (153.49300 -28.16960)
# 1152    1  POINT (152.50700 -28.25220)
# 1153    1  POINT (152.49900 -28.25670)

# %%
labels.crs is None
# Out:
# True

# %%
labels = labels.set_crs('epsg:32755')
labels.crs is None
# Out:
# False

# %%
model_pipeline = make_pipeline(StandardScaler(), KNeighborsClassifier()) # SelectKBest(k=3),

# %%
cv = CrossValidatorWrapper(KFold(n_splits=5))

# %%
params = {'n_neighbors': [4, 6, 8,]}

# %%
gridsearch = GridSearchCV(model_pipeline, cv=cv, scoring='balanced_accuracy', param_grid=params)

# %%
gridsearch
# Out:
# GridSearchCV(cv=<sklearn_xarray.model_selection.CrossValidatorWrapper object at 0x7f9d76678640>,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('kneighborsclassifier',
#                                         KNeighborsClassifier())]),
#              param_grid={'n_neighbors': [4, 6, 8]},
#              scoring='balanced_accuracy')

# %%
rlist
# Out:
# ['Rasters/tempann.tif',
#  'Rasters/vegsys.tif',
#  'Rasters/solrad.tif',
#  'Rasters/topo.tif',
#  'Rasters/raindq.tif',
#  'Rasters/cti.tif',
#  'Rasters/mi.tif',
#  'Rasters/soildepth.tif',
#  'Rasters/rugged.tif',
#  'Rasters/rainann.tif',
#  'Rasters/soilfert.tif',
#  'Rasters/tempmin.tif',
#  'Rasters/disturb.tif']

# %%
# %%time
# with gw.open(rlist, chunks=(1689, 1797)) as src:
#     X, Xy, clf = fit(src, model_pipeline, labels, col="occ")

# %%
with gw.open(rlist, chunks=(1689, 1797)) as src:
    y = fit_predict(src, model_pipeline, labels, col='occ')
    print(y)

# %%
names = ['tempann','vegsys','solrad','topo','raindq','cti','mi','soildepth','rugged','rainann','soilfert','tempmin','disturb']
len(names), len(rlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 names = ['tempann','vegsys','solrad','topo','raindq','cti','mi','soildepth','rugged','rainann','soilfert','tempmin','disturb']
# ----> 2 len(names), len(rlist)
#
# NameError: name 'rlist' is not defined

# %%
# %%time
with gw.open(rlist, chunks=(1689, 1797)) as src:
    new_df = src.gw.extract('occurrence.gpkg', time_names=names, band_names=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1, in <module>
#
# NameError: name 'gw' is not defined
